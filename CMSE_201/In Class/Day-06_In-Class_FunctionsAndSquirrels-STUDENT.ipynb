# %% [markdown]
# # Day 6 In Class Assignment: A Scurry of Squirrels in Central Park

# %% [markdown]
# ### <p style="text-align: right;"> &#9989; Cesarine Graham
# <p style="text-align: right;"> &#9989; Tori, Allie, Bella, Olivia

# %% [markdown]
# ![2018%20Central%20Park%20Squirrel%20Census%20cropped.png](attachment:2018%20Central%20Park%20Squirrel%20Census%20cropped.png)

# %% [markdown]
# ## Learning Goals
#
# * Write and use functions in Python with varying types of input parameters, default parameters, and types of return values
#
# * Explore the purpose and utility of functions in writing Python code
#
# * Write and use more complex functions using Boolean logic, loops, and if/else statements

# %% [markdown]
# # Introduction
#
#
# In this assignment, you will work in pairs and with your group to write and combine functions to explore data from the [2018 Central Park Squirrel Census](https://www.thesquirrelcensus.com/).
#
# **You should not communciate with the other pairs in your group during the first part of this assignment.** Rather, you should write a function with your pair that your fellow group members would be able to use without any in depth instruction.
#
# Make sure you write comments, use descriptive variable names, and make sure that your function will work in any notebook!
#
# ## Why are we doing this?
#
# When developing code, you will often be writing code that is meant to fit into a larger project, code that someone else (or future you) may use elsewhere, or code that needs to be used for massive amounts of data. In this assignment, you will practice writing code that others will need to use as well as code that needs to be combined into a larger project. You will also apply your function to a large data set to explore how functions can help when you want to get information form a very large data set.

# %% [markdown]
# # Part 1: Writing Functions in Pairs
#
# There are 3 functions you need to write while working in pairs (among your group members). In the second part of today's assignment, you will combine the functions from each pair in your group into the function `squirrel_data_summary` found in part 2. **Pay attention to the variables types for inputs and returns.**
#
# The requirements for each function are listed below:
#
# 1. A function that takes in a **string** for the shift the squirrel was observed during ('AM' or 'PM') and returns the Booolean key word 'True' if the squirrel was observed in the AM and the Boolean key word 'False' if the squirrel was observed in the PM.
# 2. A function that takes in a **list** of primary fur colors and returns a **list** of the unique colors of squirrel as well as the number of unique primary fur colors. (**Cesarine and Bella and Olivia**)
# 3. A function that takes in **two lists**, one with True/False strings if the squirrel is approaching and one with True/False strings if the squirrel is indifferent and returns a new **list** of antics populated with 'approaching' or 'indifferent'. (**Allie and Tori**)
#
# In the cell below, there are four lists to use for testing. The `squirrel_shift` list is for testing function 1, the `squirrel_primary_fur_color` list is for testing function 2, and the `squirrel_indifferent` and `squirrel_approach` are for testing function 3. Below is a description of what the data in each list means. **Read the descriptions before you start coding!**
#
#
# ### About the Data
# You can assume that the indices for each individual list correpsond to the same squirrel. That is, the 0-th element of `squirrel_shift` corresponds to the same squirrel as the 0-th element of the other 4 lists.
#
# * `squirrel_shift` contains a string 'AM' or 'PM' for each element that indicates whether the squirrel was observed in the AM of the day or PM of the day.
# * `squirrel_primary_fur_color` contains a string for each element that indicates the primary fur color of the squirrel.
# * `squirrel_indifferent` contains a string 'True' or 'False' for each element that indicates if the squirrel was indifferent to the observer ('True') or not indifferent to the observer ('False').
# * `squirrel_approach` is the same structure as `squirrel_indifferent` but indicates if the squirrel was approaching the observer ('True') or not ('False').

# %% [markdown]
# ## 1.1 Discussion and Organization
#
# Before you break into pairs, discuss with your group what the important parts of writing a function that other people can use are and record the results of your function in the cell below.
#
# Then, record which group members will be working on which functions!

# %% [markdown]
# <font size=6 color="#009600">&#9998;</font> Allie and Tori are working on squirrel_approach and squirrel_indifferent. Me, Bella, and Olivia are working on squirrel_primary_fur_color. Whoever finishes first is working on the squirrel_shift.

# %% [markdown]
# ## 1.2 Helpful Hints and Guidance for each Function
#
# Use the information below to guide your plan for the function you and your partner are going to write!
#
# #### Function 1: Determining the Shift a Squirrel was Observed
#
# Your function should do the following:
# * Take in a string that is the shift the squirrel was observed in (use the test data as an example)
# * Use if/else statements to check if the string is 'AM' or 'PM'
# * Return the Boolean "True" if the squirrel was observed in he AM or the Boolean "False" if the squirrel was observed in the PM
#
# #### Function 2: Getting a List of Unique Fur Colors
#
# Your function should do the following:
# * Take in a list of data (use the test data as an example)
# * Loop over the list using a for or while loop
# * Use if/else statements to determine if the color should be added to you list of unique colors or not
# * Return a list of the unique colors
#
# If you aren't sure how to look for a specific value or values in a list, you can read about the uses of `in` when writing Python code [here](https://www.w3schools.com/python/ref_keyword_in.asp)
#
# #### Function 3: Sorting the Squirrel Antics
#
# Your function should do the following:
# * Take in two lists containing True/False values: one for squirrels approaching, and one for squirrels indifferent (use the test data as an example)
# * Loop over the lists with a for or while loop
# * Use if/else statements to create a new list that contains the string "approaching" if the squirrel was approaching (i.e. has the entry "True" in the list of approach data) or the string "indifferent" if the squirrel was indifferent (i.e. has the entry "True" in the list of indifferent data)
# * Returns a new list containing the antics of each squirrel

# %% [markdown]
# ## 1.3 Planning out your Function
#
# In the cell below, write out your plan for your function in plain English (commonly referred to as pseudocode). Make sure you include:
#
# * function inputs
# * function outputs
# * basic code structure (will you have loops? if/else statements? variables?)

# %% [markdown]
# <font size=6 color="#009600">&#9998;</font>
# Function inputs: gray, white, black, gray.
# Function outputs: true and false.
# basic code structure: a for loop for unique colors

# %% [markdown]
# ## 1.4 Writing your Function
#
# In the cells below, you will write your function with your partner. The lists you will use for testing your function are in the first cell. All of the lists are given, but you will only need to use the lists relevant to the function you are writing.

# %%
# data from 2018 Central Park Squirrel census 
squirrel_primary_fur_color = ["Gray", "White", "Black", "Gray"]
squirrel_approach = ["False","True","False","True"]
squirrel_indifferent = ["True", "False", "True","False"]
squirrel_shift = ["AM","AM","PM","AM"]

# %%
# code for the color function (2)
def unique_squirrel_colors(colors):
    unique_squirrel_colors = []
    for i in colors:
        if i not in(unique_squirrel_colors):
            unique_squirrel_colors.append(i)
    return unique_squirrel_colors
    
print(unique_squirrel_colors(squirrel_primary_fur_color))



# code for the shift function (1)
def squirrel_time(time):
    if time == 'AM':
        return True
    else: 
        return False
print(squirrel_time('AM'))
print(squirrel_time('PM'))



#code for the indifferent behavior(3)
squirrel_approach = ["False","True","False","True"]
squirrel_indifferent = ["True","False", "True", "False"]

def antics (squirrel_indifferent, squirrel_approach):
    results = []
    for i in range(len(squirrel_indifferent)):
        if squirrel_indifferent[i] == "True":
            results.append("Not approaching")
        elif squirrel_approach[i] == "True":
            results.append("Approaching")
        else:
            results.append("Neither")
    return results
antics(squirrel_indifferent, squirrel_approach)
# Out:
# ['Gray', 'White', 'Black']
# True
# False
# ['Not approaching', 'Approaching', 'Not approaching', 'Approaching']

# %% [markdown]
# ### 1.4.1 Testing your Function
#
# In the cells below, you need to:
# * Use the test data to show that your function works
# * Describe in words any testing you did while developing your function

# %%
# put your code here
def unique_squirrel_colors(colors):
    unique_squirrel_colors = []
    for i in colors:
        if i not in(unique_squirrel_colors):
            unique_squirrel_colors.append(i)
    return unique_squirrel_colors
    
print(unique_squirrel_colors(squirrel_primary_fur_color))

# %% [markdown]
# <font size=6 color="#009600">&#9998;</font> The function creates an empty list that appends a new string for every new color that arises in the data set to the list.

# %% [markdown]
# ## Part 2: Putting it all together!
#
# In this part, you will work with **all** of your group members to use your functions to help you build the `squirrel_data_summary` function.
#
# ### 2.1 Sharing your work
#
# The first step is to make sure everyone has a copy of the functions. Without making any edits to your original functions, copy your pair's function and distribute it to the other pairs (you can use Slack, Teams, Email, etc.). In the cell(s) below, add the functions from the other pairs.

# %%
# Add the additional functions here
# code for the color function (2)
def unique_squirrel_colors(colors):
    unique_squirrel_colors = []
    for i in colors:
        if i not in(unique_squirrel_colors):
            unique_squirrel_colors.append(i)
    return unique_squirrel_colors
    
print(unique_squirrel_colors(squirrel_primary_fur_color))



# code for the shift function (1)
def squirrel_time(time):
    if time == 'AM':
        return True
    else: 
        return False
print(squirrel_time('AM'))
print(squirrel_time('PM'))



#code for the indifferent behavior(3)
squirrel_approach = ["False","True","False","True"]
squirrel_indifferent = ["True","False", "True", "False"]

def antics (squirrel_indifferent, squirrel_approach):
    results = []
    for i in range(len(squirrel_indifferent)):
        if squirrel_indifferent[i] == "True":
            results.append("Not approaching")
        elif squirrel_approach[i] == "True":
            results.append("Approaching")
        else:
            results.append("Neither")
    return results
antics(squirrel_indifferent, squirrel_approach)

# %% [markdown]
# ### 2.2 Testing Individual Functions
#
# In the cell(s) below, test the additional functions using the test data, and answer the following questions:
# 1. Did the  function(s) work the first time you tested them?
# 2. If not, what changes did you need to do so that they would run? If they did run, what about the functions made them easy to use directly?
# 3. Describe a challenge you could run into when you and your group try to call these functions in another function?

# %%
# Put your tests here

# %% [markdown]
# <font size=6 color="#009600">&#9998;</font> The functions work

# %% [markdown]
# ## 2.2.1 Calling Functions Inside Other Functions
#
# Now that you know your individual functions work, it's time to write some test code to combine them before you write your `squirrel_data_summary` function! In the cell below, write a `test` function that takes in the **four lists** of test data and does the following:
#
# 1. Calls your color function and saves it to a variable
# 2. Calls your antics function and saves it to a variable
# 3. Loops over the shift list, calling your shift function each time, and prints the output
# 4. Return your color and antics variables.
#
# Make sure to test your combined function as you work to make sure it is working how you intend!
#
# # Once you have finished **CHECK WITH AN INSTRUCTOR**

# %%
# put your code here
# code for the color function (2)
def unique_squirrel_colors(colors):
    unique_squirrel_colors = []
    for i in colors:
        if i not in(unique_squirrel_colors):
            unique_squirrel_colors.append(i)
    return unique_squirrel_colors
    
print(unique_squirrel_colors(squirrel_primary_fur_color))



# code for the shift function (1)
def squirrel_time(time):
    if time == 'AM':
        return True
    else: 
        return False
print(squirrel_time('AM'))
print(squirrel_time('PM'))



#code for the indifferent behavior(3)
squirrel_approach = ["False","True","False","True"]
squirrel_indifferent = ["True","False", "True", "False"]

def antics (squirrel_indifferent, squirrel_approach):
    results = []
    for i in range(len(squirrel_indifferent)):
        if squirrel_indifferent[i] == "True":
            results.append("Not approaching")
        elif squirrel_approach[i] == "True":
            results.append("Approaching")
        else:
            results.append("Neither")
    return results
antics(squirrel_indifferent, squirrel_approach)
# Out:
# ['Gray', 'White', 'Black']
# True
# False
# ['Not approaching', 'Approaching', 'Not approaching', 'Approaching']

# %% [markdown]
# ### 2.3 Planning your Function
#
# Now that you know that your smaller functions work and how to call a function within a function, it's time to think about how you can combine your three functions to get a summary of basic information from the squirrel data.
#
# Your function must do the following:
# * Take **four** lists as inputs (a fur color list, an approaching list, an indifferent list, and a shift list)
# * Call Function 2 (unique fur colors) and Function 3 (sorting squirrel antics) and save the results to variables
# * Use a for or while loop and if/else statements to determine the total number of squirrels observed in each shift, the number of squirrels in each shift that were approaching, and the number of squirrels in each shift that were indifferent
# * Calculate the percentage of squirrels observed in each shift
# * Calculate the percentage of squirrels in each shift that were approaching
# * Return the percentages, the total number of squirrels, and the list of unique colors
#
# **Reminder:**
#
# $ \mathrm{Percentage} = \frac{{value}}{\mathrm{total \ value}} \times 100 $
#
# ------------------
#
# ### 2.3.1 Task
#
# With your whole group, come up with a plan written in plain English (pseudocode) for your `squirrel_data_summary` function. In the cell below, write down the results of your discussion (including the pseudocode). You can use your tests from 2.2.1 as a starting point.

# %% [markdown]
# <font size=6 color="#009600">&#9998;</font> *Put your answers here.*

# %% [markdown]
# ### 2.4 Writing your Function
#
# In the`squirrel_data_summary` function below, work together as a group to implement your plan from 2.3 to write your function. Use the test data from Part 1 as you work to make sure your function is working as you want it to!

# %%
# Put your code here

def get_percent (val, total):
    return val / float(total) * 100.0

def squirrel_data_summary(squirrel_primary_fur_color, squirrel_shift, squirrel_indifferent, squirrel_approach):
    u_colors = unique_squirrel_colors(squirrel_primary_fur_color)
    squirrel_stuff = antics(squirrel_indifferent, squirrel_approach)
    count_am, count_am_ap, count_am_indif = 0.0,0.0,0.0
    count_pm, count_pm_ap, count_pm_indif = 0.0,0.0,0.0
    results = []
    
    for i in range(len(squirrel_shift)):
        if squirrel_time(squirrel_shift[i]):
            count_am += 1
            if squirrel_stuff[i] == "Approaching":
                count_am_ap += 1
            else:
                count_am_indif += 1
            
        else:
            count_pm += 1    
            if squirrel_stuff[i] == "Approaching":
                count_pm_ap += 1
            else:
                count_pm_indif += 1
    
    results.append(get_percent(count_am, len(squirrel_shift)))
    
    return results
squirrel_data_summary(squirrel_primary_fur_color, squirrel_shift, squirrel_indifferent, squirrel_approach)
# Out:
# [75.0]

# %% [markdown]
# ### 2.5 Using your Function
#
# Now that you have a working `squirrel_data_summary`, use your function to get information about the squirrel data in the cell below, and answer the questions.

# %%
# Full lists of squirrel data
fur_color_full =  ['Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Chestnut Brown', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Chestnut Brown', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Gray', 'Gray', 'Chestnut Brown', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'White', 'Gray', 'Gray', 'Gray', 'Black', 'Black', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Black', 'Gray', 'Gray', 'Gray', 'White', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Cinnamon', 'Cinnamon', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Cinnamon', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Gray', 'Black', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Black', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Cinnamon', 'Gray', 'Black', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Gray', 'Cinnamon', 'Black', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Black', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Black', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Cinnamon', 'Gray', 'Black', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Cinnamon', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Cinnamon', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Black', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Black', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Black', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Cinnamon', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Cinnamon', 'Cinnamon', 'Gray', 'Gray', 'Black', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Cinnamon', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Black', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Black', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Black', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Black', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Cinnamon', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Black', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Cinnamon', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Cinnamon', 'Cinnamon', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Black', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Cinnamon', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Cinnamon', 'Black', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Black', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Black', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Cinnamon', 'Gray', 'Cinnamon', 'Black', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Black', 'Gray', 'Cinnamon', 'Gray', 'Cinnamon', 'Cinnamon', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Cinnamon', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Black', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Cinnamon', 'Cinnamon', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Black', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Black', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Black', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Black', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Cinnamon', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Cinnamon', 'Gray', 'Black', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Cinnamon', 'Cinnamon', 'Gray', 'Gray', 'Black', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Gray', 'Black', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Black', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Cinnamon', 'Gray', 'Cinnamon', 'Cinnamon', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Cinnamon', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Black', 'Gray', 'Black', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Cinnamon', 'Gray', 'Gray', 'Black', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Cinnamon', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Black', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Black', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Black', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Black', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Cinnamon', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Black', 'Cinnamon', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Cinnamon', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Cinnamon', 'Black', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Cinnamon', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Black', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Black', 'Gray', 'Cinnamon', 'Cinnamon', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Black', 'Black', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Black', 'Cinnamon', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Black', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon', 'Gray', 'Gray', 'Gray', 'Gray', 'Cinnamon'] 
approach_full = ['False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'True', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'True', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'True', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True'] 
indifferent_full =  ['False', 'False', 'False', 'True', 'False', 'True', 'False', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'True', 'True', 'False', 'False', 'True', 'False', 'False', 'True', 'False', 'False', 'True', 'True', 'False', 'True', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'True', 'True', 'True', 'True', 'False', 'True', 'False', 'False', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'False', 'False', 'False', 'True', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'True', 'True', 'False', 'True', 'True', 'False', 'True', 'False', 'False', 'False', 'False', 'True', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'True', 'True', 'False', 'True', 'False', 'False', 'False', 'True', 'False', 'False', 'True', 'False', 'False', 'True', 'False', 'True', 'False', 'False', 'True', 'False', 'True', 'False', 'False', 'False', 'False', 'True', 'False', 'True', 'True', 'False', 'False', 'False', 'True', 'True', 'False', 'True', 'False', 'False', 'True', 'True', 'False', 'True', 'False', 'False', 'True', 'False', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'True', 'True', 'False', 'False', 'True', 'False', 'False', 'False', 'True', 'True', 'True', 'False', 'False', 'True', 'False', 'True', 'True', 'True', 'True', 'False', 'True', 'False', 'True', 'False', 'True', 'True', 'True', 'False', 'True', 'False', 'False', 'True', 'True', 'False', 'False', 'True', 'False', 'False', 'False', 'True', 'True', 'True', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'True', 'False', 'True', 'False', 'False', 'False', 'True', 'True', 'False', 'False', 'True', 'True', 'False', 'False', 'False', 'True', 'False', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'False', 'False', 'True', 'False', 'True', 'True', 'True', 'False', 'False', 'False', 'True', 'False', 'True', 'False', 'False', 'True', 'True', 'False', 'True', 'True', 'False', 'False', 'True', 'True', 'False', 'True', 'False', 'False', 'True', 'True', 'True', 'True', 'False', 'True', 'False', 'False', 'True', 'True', 'True', 'False', 'True', 'False', 'True', 'True', 'True', 'False', 'False', 'True', 'True', 'False', 'True', 'True', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'True', 'False', 'False', 'False', 'True', 'False', 'False', 'True', 'True', 'True', 'True', 'True', 'False', 'False', 'True', 'False', 'False', 'True', 'False', 'False', 'True', 'False', 'False', 'False', 'True', 'True', 'True', 'True', 'True', 'False', 'False', 'False', 'True', 'True', 'True', 'False', 'True', 'False', 'True', 'True', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'True', 'False', 'True', 'False', 'False', 'False', 'False', 'True', 'False', 'True', 'True', 'True', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'True', 'False', 'False', 'True', 'False', 'True', 'True', 'True', 'False', 'False', 'False', 'False', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'False', 'False', 'False', 'True', 'True', 'False', 'False', 'True', 'False', 'False', 'False', 'True', 'True', 'True', 'False', 'True', 'False', 'True', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'True', 'True', 'True', 'True', 'False', 'False', 'True', 'True', 'True', 'True', 'False', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'False', 'False', 'False', 'True', 'True', 'True', 'True', 'False', 'False', 'True', 'True', 'False', 'True', 'False', 'False', 'True', 'False', 'False', 'True', 'False', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'False', 'False', 'True', 'False', 'False', 'True', 'False', 'False', 'True', 'True', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'True', 'False', 'False', 'True', 'False', 'False', 'True', 'True', 'True', 'True', 'False', 'False', 'True', 'True', 'True', 'False', 'False', 'True', 'False', 'False', 'True', 'True', 'False', 'True', 'True', 'True', 'False', 'True', 'True', 'False', 'True', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'True', 'True', 'False', 'True', 'True', 'False', 'True', 'False', 'True', 'True', 'False', 'True', 'False', 'True', 'True', 'True', 'False', 'True', 'False', 'True', 'True', 'True', 'False', 'False', 'False', 'False', 'True', 'False', 'True', 'True', 'False', 'True', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'True', 'True', 'True', 'False', 'True', 'False', 'False', 'False', 'True', 'False', 'True', 'False', 'False', 'False', 'True', 'True', 'True', 'True', 'False', 'False', 'True', 'False', 'True', 'True', 'False', 'True', 'True', 'False', 'True', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'True', 'False', 'True', 'True', 'True', 'False', 'True', 'False', 'True', 'False', 'True', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'True', 'True', 'True', 'False', 'False', 'True', 'True', 'True', 'False', 'True', 'False', 'False', 'False', 'True', 'False', 'True', 'False', 'True', 'True', 'False', 'False', 'True', 'False', 'False', 'True', 'False', 'True', 'False', 'False', 'True', 'True', 'False', 'True', 'True', 'False', 'False', 'True', 'True', 'True', 'False', 'False', 'False', 'False', 'True', 'False', 'True', 'False', 'False', 'False', 'True', 'True', 'False', 'True', 'False', 'False', 'True', 'True', 'False', 'False', 'True', 'True', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'True', 'True', 'False', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'False', 'False', 'False', 'True', 'True', 'False', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'False', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'False', 'True', 'False', 'False', 'True', 'True', 'True', 'False', 'False', 'False', 'True', 'False', 'False', 'True', 'False', 'True', 'True', 'False', 'False', 'True', 'False', 'True', 'False', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'False', 'True', 'False', 'False', 'False', 'False', 'True', 'False', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'False', 'False', 'False', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'False', 'False', 'True', 'True', 'True', 'False', 'False', 'True', 'True', 'False', 'False', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'False', 'False', 'False', 'True', 'False', 'True', 'False', 'False', 'True', 'True', 'True', 'True', 'True', 'False', 'False', 'True', 'False', 'True', 'True', 'False', 'True', 'True', 'False', 'False', 'True', 'True', 'True', 'True', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'True', 'True', 'False', 'True', 'False', 'True', 'True', 'False', 'True', 'False', 'False', 'False', 'True', 'True', 'True', 'False', 'False', 'False', 'False', 'False', 'True', 'True', 'True', 'True', 'False', 'False', 'False', 'False', 'True', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'True', 'True', 'False', 'False', 'True', 'False', 'False', 'True', 'False', 'False', 'True', 'True', 'False', 'True', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'True', 'True', 'True', 'True', 'False', 'False', 'False', 'True', 'False', 'False', 'True', 'False', 'False', 'True', 'True', 'False', 'False', 'True', 'True', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'True', 'False', 'True', 'False', 'True', 'False', 'True', 'False', 'False', 'True', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'True', 'False', 'True', 'False', 'True', 'False', 'True', 'False', 'False', 'True', 'True', 'True', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'True', 'False', 'False', 'False', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'False', 'True', 'True', 'False', 'True', 'False', 'True', 'False', 'False', 'True', 'False', 'False', 'True', 'True', 'False', 'False', 'True', 'True', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'True', 'False', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'False', 'False', 'True', 'True', 'True', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'True', 'True', 'True', 'False', 'False', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'False', 'False', 'True', 'False', 'False', 'True', 'True', 'True', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'True', 'True', 'True', 'False', 'False', 'False', 'False', 'False', 'True', 'True', 'False', 'False', 'True', 'False', 'False', 'True', 'False', 'False', 'True', 'True', 'True', 'True', 'False', 'False', 'True', 'False', 'True', 'False', 'False', 'True', 'True', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'True', 'False', 'True', 'True', 'False', 'True', 'False', 'True', 'False', 'False', 'False', 'True', 'False', 'True', 'True', 'True', 'False', 'True', 'True', 'False', 'True', 'True', 'False', 'False', 'True', 'True', 'True', 'False', 'False', 'True', 'False', 'True', 'True', 'False', 'False', 'True', 'True', 'False', 'True', 'False', 'False', 'True', 'False', 'False', 'False', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'False', 'False', 'True', 'True', 'True', 'False', 'False', 'False', 'True', 'True', 'False', 'True', 'False', 'True', 'True', 'True', 'False', 'False', 'False', 'True', 'False', 'True', 'False', 'False', 'False', 'True', 'False', 'False', 'True', 'True', 'True', 'True', 'False', 'True', 'False', 'True', 'False', 'True', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'True', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'True', 'True', 'False', 'False', 'True', 'False', 'False', 'False', 'True', 'False', 'True', 'False', 'False', 'False', 'True', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'True', 'True', 'False', 'False', 'False', 'False', 'True', 'False', 'True', 'True', 'True', 'False', 'True', 'False', 'False', 'False', 'True', 'False', 'True', 'False', 'True', 'True', 'False', 'True', 'False', 'True', 'True', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'True', 'True', 'False', 'False', 'True', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'True', 'True', 'True', 'False', 'True', 'False', 'False', 'False', 'True', 'True', 'False', 'True', 'True', 'True', 'False', 'False', 'True', 'True', 'False', 'True', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'True', 'False', 'True', 'False', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'False', 'True', 'True', 'False', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'False', 'True', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'True', 'True', 'False', 'False', 'False', 'True', 'False', 'True', 'True', 'False', 'True', 'False', 'False', 'True', 'False', 'False', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'False', 'False', 'True', 'False', 'True', 'True', 'False', 'True', 'True', 'False', 'False', 'False', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'True', 'True', 'True', 'True', 'False', 'True', 'False', 'False', 'True', 'True', 'True', 'False', 'True', 'True', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'True', 'True', 'False', 'False', 'False', 'False', 'True', 'True', 'False', 'False', 'False', 'False', 'True', 'True', 'True', 'False', 'False', 'False', 'True', 'False', 'True', 'False', 'True', 'True', 'False', 'True', 'True', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'True', 'True', 'True', 'True', 'False', 'False', 'False', 'True', 'True', 'True', 'False', 'False', 'False', 'True', 'True', 'False', 'True', 'True', 'True', 'False', 'False', 'False', 'True', 'False', 'True', 'False', 'False', 'True', 'False', 'True', 'True', 'False', 'False', 'False', 'False', 'True', 'True', 'True', 'False', 'False', 'True', 'True', 'False', 'False', 'False', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'False', 'True', 'True', 'False', 'True', 'True', 'False', 'True', 'False', 'True', 'True', 'False', 'False', 'False', 'True', 'False', 'False', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'False', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'True', 'False', 'True', 'False', 'False', 'False', 'True', 'False', 'False', 'True', 'True', 'True', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'True', 'False', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'False', 'False', 'False', 'False', 'True', 'True', 'False', 'False', 'False', 'True', 'True', 'False', 'False', 'False', 'True', 'True', 'True', 'True', 'True', 'False', 'False', 'True', 'True', 'True', 'True', 'False', 'False', 'False', 'True', 'True', 'True', 'False', 'True', 'False', 'False', 'True', 'True', 'True', 'True', 'False', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'False', 'False', 'True', 'True', 'True', 'False', 'False', 'True', 'False', 'True', 'True', 'False', 'False', 'False', 'False', 'True', 'True', 'True', 'False', 'True', 'True', 'False', 'False', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'False', 'True', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'True', 'True', 'False', 'False', 'True', 'False', 'False', 'True', 'True', 'True', 'True', 'False', 'True', 'False', 'True', 'True', 'False', 'True', 'False', 'True', 'True', 'False', 'True', 'True', 'False', 'False', 'False', 'True', 'False', 'True', 'False', 'False', 'True', 'False', 'False', 'False', 'True', 'True', 'True', 'False', 'True', 'True', 'False', 'True', 'False', 'False', 'False', 'True', 'True', 'False', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'True', 'False', 'False', 'False', 'False', 'True', 'False', 'True', 'False', 'True', 'False', 'True', 'True', 'True', 'False', 'False', 'True', 'True', 'True', 'True', 'False', 'True', 'False', 'True', 'False', 'True', 'True', 'True', 'False', 'False', 'True', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'True', 'True', 'False', 'False', 'True', 'True', 'False', 'True', 'True', 'True', 'False', 'True', 'True', 'False', 'False', 'False', 'True', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'True', 'False', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'False', 'True', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'True', 'False', 'True', 'True', 'False', 'False', 'False', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'False', 'False', 'True', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'True', 'True', 'False', 'False', 'False', 'True', 'False', 'True', 'False', 'True', 'True', 'False', 'True', 'False', 'False', 'True', 'False', 'True', 'True', 'True', 'False', 'True', 'True', 'False', 'True', 'True', 'False', 'True', 'True', 'False', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'False', 'False', 'False', 'True', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'True', 'True', 'True', 'False', 'False', 'True', 'True', 'False', 'False', 'True', 'True', 'False', 'False', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'False', 'False', 'True', 'False', 'True', 'False', 'False', 'True', 'False', 'True', 'False', 'False', 'False', 'True', 'True', 'False', 'True', 'False', 'True', 'False', 'True', 'False', 'True', 'False', 'True', 'False', 'True', 'True', 'False', 'False', 'True', 'True', 'True', 'True', 'False', 'False', 'True', 'False', 'True', 'False', 'False', 'False', 'True', 'False', 'True', 'True', 'False', 'False', 'True', 'False', 'True', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'True', 'True', 'True', 'False', 'True', 'True', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'True', 'True', 'True', 'False', 'True', 'True', 'False', 'True', 'True', 'False', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'False', 'True', 'True', 'False', 'True', 'True', 'False', 'False', 'False', 'False', 'True', 'True', 'True', 'False', 'False', 'True', 'True', 'False', 'False', 'True', 'False', 'True', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'True', 'False', 'True', 'False', 'False', 'True', 'False', 'False', 'True', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'True', 'True', 'False', 'True', 'False', 'False', 'True', 'True', 'False', 'True', 'True', 'False', 'False', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'True', 'True', 'True', 'True', 'True', 'False', 'False', 'False', 'True', 'False', 'True', 'True', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'False', 'False', 'True', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'True', 'True', 'True', 'False', 'False', 'False', 'True', 'False', 'False', 'True', 'True', 'False', 'True', 'True', 'True', 'False', 'False', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'True', 'False', 'True', 'True', 'False', 'False', 'True', 'False', 'False', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'False', 'False', 'True', 'True', 'False', 'False', 'False', 'True', 'False', 'False', 'True', 'False', 'False', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'True', 'False', 'True', 'False', 'True', 'True', 'False', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'False', 'True', 'True', 'True', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'True', 'True', 'False', 'False', 'True', 'True', 'False', 'True', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'True', 'False', 'False', 'False', 'False', 'True', 'True', 'False', 'True', 'False', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'False', 'True', 'False', 'False', 'True', 'False', 'False', 'True', 'False', 'False', 'True', 'True', 'False', 'True', 'False', 'True', 'True', 'False', 'False', 'True', 'False', 'False', 'True', 'False', 'False', 'False', 'True', 'False', 'True', 'False', 'False', 'False', 'False', 'True', 'True', 'False', 'False', 'True', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'True', 'True', 'True', 'False', 'False', 'False', 'True', 'False', 'True', 'False', 'True', 'True', 'False', 'True', 'True', 'False', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'False', 'False', 'False', 'True', 'False', 'False', 'True', 'False', 'False', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'True', 'True', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'True', 'True', 'False', 'False', 'False', 'True', 'True', 'False', 'True', 'False', 'False', 'False', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'False', 'True', 'False', 'True', 'True', 'True', 'False', 'False', 'True', 'True', 'False', 'True', 'False', 'False', 'True', 'True', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'False', 'False', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'False', 'False', 'False', 'True', 'True', 'False', 'True', 'False', 'False', 'True', 'False', 'False', 'False', 'True', 'True', 'False', 'True', 'False', 'False', 'False', 'True', 'True', 'False', 'False', 'False', 'True', 'True', 'True', 'True', 'False', 'True', 'False', 'False', 'True', 'False', 'False', 'True', 'True', 'False', 'True', 'True', 'True', 'False', 'False', 'True', 'True', 'True', 'False', 'False', 'True', 'False', 'False', 'True', 'False', 'False', 'True', 'True', 'False', 'False', 'True', 'False', 'False', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'False', 'False', 'True', 'False', 'False', 'False', 'True', 'False', 'False', 'True', 'True', 'True', 'True', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'True', 'False', 'True', 'False', 'True', 'True', 'False', 'False', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'False', 'True', 'False', 'True', 'True', 'True', 'False', 'True', 'False', 'True', 'False', 'True', 'False', 'True', 'True', 'True', 'False', 'False', 'True', 'False', 'False', 'True', 'True', 'False', 'False', 'True', 'False', 'False', 'True', 'True', 'True', 'False', 'False', 'True', 'True', 'False', 'True', 'False', 'False', 'True', 'True', 'False', 'False', 'False', 'True', 'True', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'True', 'True', 'True', 'False', 'False', 'True', 'True', 'True', 'True', 'False', 'False', 'False', 'True', 'True', 'True', 'False', 'True', 'False', 'False', 'False', 'False', 'True', 'False', 'True', 'True', 'False', 'True', 'False', 'True', 'True', 'False', 'True', 'False', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'False', 'False', 'False', 'True', 'True', 'False', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'False', 'True', 'False', 'False', 'False', 'True', 'True', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'True', 'True', 'True', 'False', 'False', 'False', 'True', 'False', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'False', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'False', 'True', 'False', 'True', 'False', 'False', 'True', 'True', 'False', 'True', 'False', 'True', 'True', 'True', 'False', 'True', 'True', 'False', 'True', 'False', 'False', 'False', 'True', 'True', 'True', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'True', 'False', 'False', 'True', 'True', 'False', 'False', 'True', 'False', 'True', 'True', 'False', 'False', 'False', 'False', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'False', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'True', 'True', 'False', 'True', 'False', 'True', 'False', 'True', 'True', 'False', 'False', 'True', 'False', 'False', 'True', 'True', 'True', 'True', 'False', 'False', 'True', 'False', 'True', 'True', 'True', 'False', 'False', 'False', 'True', 'True', 'False', 'False', 'True', 'False', 'True', 'True', 'False', 'False', 'False', 'False', 'True', 'True', 'True', 'True', 'False', 'False', 'True', 'False', 'True', 'True', 'True', 'False', 'True', 'False', 'False', 'True', 'True', 'True', 'True', 'False', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'True', 'False', 'False', 'False', 'False', 'False', 'True', 'True', 'False', 'False', 'True', 'False', 'False', 'True', 'True', 'True', 'False'] 
shift_full =  ['PM', 'PM', 'AM', 'AM', 'AM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'AM', 'AM', 'AM', 'AM', 'PM', 'AM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'AM', 'AM', 'PM', 'AM', 'AM', 'PM', 'AM', 'PM', 'AM', 'AM', 'PM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'AM', 'PM', 'AM', 'PM', 'AM', 'PM', 'AM', 'PM', 'AM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'PM', 'AM', 'AM', 'AM', 'AM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'AM', 'AM', 'PM', 'PM', 'AM', 'AM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'AM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'AM', 'AM', 'AM', 'AM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'PM', 'AM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'AM', 'AM', 'PM', 'AM', 'AM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'AM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'AM', 'AM', 'AM', 'AM', 'AM', 'PM', 'PM', 'AM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'AM', 'PM', 'AM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'AM', 'AM', 'AM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'AM', 'AM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'AM', 'AM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'AM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'AM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'AM', 'AM', 'PM', 'PM', 'AM', 'AM', 'AM', 'AM', 'PM', 'PM', 'AM', 'AM', 'PM', 'PM', 'AM', 'AM', 'PM', 'AM', 'AM', 'AM', 'AM', 'PM', 'AM', 'AM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'AM', 'AM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'AM', 'PM', 'AM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'AM', 'AM', 'PM', 'AM', 'PM', 'AM', 'AM', 'PM', 'AM', 'AM', 'PM', 'AM', 'AM', 'PM', 'PM', 'AM', 'PM', 'AM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'AM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'AM', 'AM', 'AM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'AM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'AM', 'PM', 'PM', 'AM', 'AM', 'AM', 'AM', 'AM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'AM', 'AM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'AM', 'PM', 'AM', 'AM', 'AM', 'AM', 'AM', 'PM', 'AM', 'AM', 'AM', 'AM', 'AM', 'PM', 'AM', 'PM', 'PM', 'AM', 'AM', 'AM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'AM', 'PM', 'AM', 'AM', 'AM', 'PM', 'AM', 'AM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'AM', 'AM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'AM', 'AM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'AM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'AM', 'AM', 'AM', 'AM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'AM', 'AM', 'AM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'AM', 'AM', 'PM', 'AM', 'AM', 'AM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'AM', 'AM', 'AM', 'AM', 'AM', 'AM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'AM', 'PM', 'AM', 'AM', 'AM', 'AM', 'AM', 'AM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'AM', 'AM', 'AM', 'AM', 'PM', 'AM', 'AM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'AM', 'PM', 'PM', 'AM', 'PM', 'AM', 'AM', 'AM', 'AM', 'AM', 'PM', 'AM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'AM', 'AM', 'AM', 'AM', 'PM', 'AM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'AM', 'AM', 'PM', 'AM', 'PM', 'PM', 'AM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'AM', 'AM', 'AM', 'PM', 'AM', 'AM', 'PM', 'AM', 'PM', 'PM', 'AM', 'AM', 'PM', 'PM', 'AM', 'AM', 'AM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'AM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'AM', 'AM', 'PM', 'AM', 'PM', 'AM', 'AM', 'AM', 'AM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'AM', 'AM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'PM', 'AM', 'AM', 'PM', 'AM', 'PM', 'AM', 'AM', 'AM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'AM', 'AM', 'PM', 'AM', 'AM', 'AM', 'AM', 'AM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'AM', 'AM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'AM', 'PM', 'AM', 'AM', 'PM', 'PM', 'AM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'AM', 'AM', 'AM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'AM', 'AM', 'PM', 'AM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'AM', 'AM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'AM', 'AM', 'PM', 'AM', 'AM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'AM', 'PM', 'PM', 'AM', 'AM', 'AM', 'AM', 'PM', 'PM', 'AM', 'PM', 'AM', 'AM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'AM', 'PM', 'AM', 'PM', 'AM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'AM', 'AM', 'AM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'AM', 'AM', 'AM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'AM', 'AM', 'AM', 'AM', 'AM', 'PM', 'AM', 'AM', 'AM', 'AM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'AM', 'PM', 'AM', 'AM', 'AM', 'PM', 'AM', 'AM', 'PM', 'PM', 'AM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'AM', 'AM', 'AM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'AM', 'AM', 'PM', 'PM', 'AM', 'AM', 'PM', 'AM', 'AM', 'AM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'AM', 'AM', 'AM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'AM', 'AM', 'AM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'AM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'AM', 'AM', 'AM', 'PM', 'PM', 'AM', 'PM', 'AM', 'AM', 'AM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'PM', 'AM', 'AM', 'AM', 'AM', 'AM', 'PM', 'PM', 'AM', 'AM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'AM', 'AM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'AM', 'AM', 'AM', 'AM', 'AM', 'PM', 'AM', 'PM', 'AM', 'AM', 'PM', 'AM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'AM', 'PM', 'AM', 'AM', 'PM', 'AM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'AM', 'AM', 'AM', 'AM', 'PM', 'AM', 'PM', 'PM', 'AM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'AM', 'AM', 'AM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'AM', 'AM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'AM', 'AM', 'AM', 'PM', 'PM', 'AM', 'AM', 'AM', 'AM', 'AM', 'PM', 'AM', 'PM', 'AM', 'AM', 'AM', 'AM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'AM', 'PM', 'AM', 'AM', 'AM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'AM', 'PM', 'PM', 'AM', 'AM', 'PM', 'PM', 'AM', 'PM', 'AM', 'AM', 'AM', 'PM', 'AM', 'PM', 'AM', 'AM', 'AM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'AM', 'PM', 'AM', 'PM', 'AM', 'AM', 'AM', 'AM', 'AM', 'PM', 'AM', 'PM', 'PM', 'AM', 'AM', 'AM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'AM', 'AM', 'PM', 'AM', 'AM', 'PM', 'AM', 'PM', 'AM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'AM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'AM', 'AM', 'AM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'AM', 'PM', 'PM', 'AM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'AM', 'PM', 'AM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'AM', 'AM', 'AM', 'AM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'AM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'AM', 'AM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'AM', 'AM', 'AM', 'AM', 'AM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'AM', 'AM', 'PM', 'AM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'AM', 'AM', 'PM', 'AM', 'PM', 'PM', 'AM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'AM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'AM', 'AM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'AM', 'PM', 'AM', 'PM', 'PM', 'AM', 'AM', 'PM', 'PM', 'AM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'AM', 'PM', 'AM', 'PM', 'AM', 'AM', 'PM', 'PM', 'AM', 'AM', 'AM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'AM', 'AM', 'PM', 'PM', 'AM', 'AM', 'PM', 'PM', 'AM', 'AM', 'PM', 'AM', 'PM', 'PM', 'AM', 'AM', 'AM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'AM', 'AM', 'AM', 'PM', 'AM', 'AM', 'AM', 'PM', 'AM', 'AM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'AM', 'AM', 'PM', 'AM', 'AM', 'PM', 'PM', 'AM', 'AM', 'AM', 'AM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'AM', 'PM', 'AM', 'AM', 'PM', 'AM', 'AM', 'AM', 'AM', 'PM', 'PM', 'AM', 'AM', 'AM', 'PM', 'AM', 'PM', 'AM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'PM', 'AM', 'AM', 'AM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'AM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'AM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'PM', 'AM', 'AM', 'AM', 'PM', 'PM', 'AM', 'AM', 'AM', 'PM', 'AM', 'PM', 'AM', 'PM', 'AM', 'PM', 'AM', 'AM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'AM', 'PM', 'AM', 'AM', 'PM', 'AM', 'PM', 'AM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'AM', 'AM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'AM', 'AM', 'PM', 'AM', 'AM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'AM', 'AM', 'AM', 'PM', 'AM', 'AM', 'AM', 'AM', 'PM', 'AM', 'AM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'AM', 'AM', 'AM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'AM', 'PM', 'AM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'AM', 'AM', 'AM', 'AM', 'PM', 'AM', 'PM', 'AM', 'AM', 'AM', 'AM', 'PM', 'AM', 'PM', 'AM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'AM', 'AM', 'AM', 'PM', 'AM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'AM', 'AM', 'PM', 'PM', 'AM', 'PM', 'AM', 'AM', 'AM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'AM', 'AM', 'PM', 'PM', 'AM', 'PM', 'AM', 'AM', 'AM', 'AM', 'PM', 'AM', 'PM', 'AM', 'AM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'AM', 'PM', 'AM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'AM', 'AM', 'PM', 'AM', 'AM', 'AM', 'AM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'AM', 'AM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'AM', 'AM', 'PM', 'PM', 'AM', 'PM', 'AM', 'AM', 'AM', 'PM', 'AM', 'PM', 'PM', 'AM', 'AM', 'AM', 'AM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'AM', 'AM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'AM', 'AM', 'AM', 'AM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'AM', 'AM', 'AM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'AM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'AM', 'AM', 'AM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'AM', 'AM', 'AM', 'AM', 'AM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'AM', 'PM', 'AM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'AM', 'AM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'AM', 'AM', 'AM', 'PM', 'AM', 'AM', 'AM', 'PM', 'AM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'AM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'AM', 'PM', 'AM', 'AM', 'AM', 'AM', 'PM', 'PM', 'AM', 'PM', 'AM', 'AM', 'AM', 'AM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'AM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'AM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'AM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'AM', 'PM', 'PM', 'PM', 'PM', 'PM', 'AM', 'PM', 'AM', 'PM', 'AM', 'PM', 'AM', 'PM', 'PM', 'PM', 'PM']

# %%
# Call your function here

# %% [markdown]
# ### 2.5.1 Questions
#
# Fill in your answers to the questions here:
#
# 1. Did your function work the first time you tried it?
# 2. If it did not, what changes did you need to make for it to work? If it did, what about your function made it work easily on a large data set?

# %% [markdown]
# <font size=6 color="#009600">&#9998;</font> *Put your answers here.*

# %% [markdown]
# # Part 3: Reflections
#
# Sometimes, throughout the semester, we will ask you to refect on your experiences as a tool to help you self-assess your understanding of course material and how you are feeling about your own work and your group's work. Please answer the guiding questions below as completely as you can, even if you did not complete Part 2.
#
# 1. What challenges did your group encounter while developing the functions for today's class (in your pairs and full group)?
#
# 2. Today's assignment required a mix of small and larger group work. How well do you feel that you contributed to your group in that setting? How did your group work together in general?
#
# 3. If your group had challenges working together, what changes should your group make going forward to work together more effectively? What changes can you make to your own contributions?
#
# 4. Functions are a challenging topic in learning to write code to solve problems. If you were tutoring a student in CMSE 201, how would you explain functions to them?
#
# 5. We still have quite a bit of the semester left, how do you see yourself using functions in your code throughout the semester?

# %% [markdown]
# <font size=6 color="#009600">&#9998;</font> *Put your answers here.*
#
# 1. ...
#
# 2. ...
#
# 3. ...
#
# 4. ...
#
# 5. ...

# %% [markdown]
# ---
# ## Assignment wrapup
#
# Please fill out the form that appears when you run the code below. **You must completely fill this out in order to receive credit for the assignment!**

# %% [markdown]
# ---

# %%
from IPython.display import HTML
HTML(
"""
<iframe 
	src="https://cmse.msu.edu/cmse201-ic-survey" 
	width="800px" 
	height="600px" 
	frameborder="0" 
	marginheight="0" 
	marginwidth="0">
	Loading...
</iframe>
"""
)
# Out:
# <iframe
# 	src="https://cmse.msu.edu/cmse201-ic-survey"
# 	width="800px"
# 	height="600px"
# 	frameborder="0"
# 	marginheight="0"
# 	marginwidth="0">
# 	Loading...
# </iframe>

# %% [markdown]
# ## Congratulations, you're done!
#
# Submit this assignment by uploading it to the course Desire2Learn web page.  Go to the "In-class assignments" folder, find the appropriate submission link, and upload it there.
#
# See you next class!

# %% [markdown]
# -----------
# ### Acknowledgements
#
# Data comes from 2018 Central Park Squirrel Census
#
# Inspiration from Rachel Roca, CMSE/Mathematics graduate student, CMSE 201 TA

# %% [markdown]
# &#169; Copyright 2022,  Michigan State University Board of Trustees
